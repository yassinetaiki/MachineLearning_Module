# %%
import numpy as np
import matplotlib.pyplot as plt 
import pandas as pd 
from sklearn.datasets import load_iris
import seaborn as sns 




bit=pd.read_csv('bitcoin.csv')
#print(bit.head())
#print(bit['Open'].shape)
#print(bit['Close'].shape)
#plt.scatter(bit['Open'],bit['Close'],c=bit['Close'])  
#sns.pairplot(bit,hue = 'Open')

titanic=pd.read_excel('titanic.xls')
titanic.drop(['body','boat','home.dest'],axis=1,inplace=True)
titanic.dropna(axis=0,inplace=True)
titanic.shape
sns.pairplot(titanic) ##on va remarquer qu'on a des graphiques alignees car on a plein de variables qui compose des categories 
sns.catplot(x='pclass',y='age',data=titanic,hue='survived') ##visuliser relation entre variables normale et categorique 
sns.boxplot(x='pclass',y='age',data=titanic,hue='survived')
sns.displot(titanic['fare'])
#sns.jointplot(titanic['fare'],titanic['age'],cmap='plasma')
sns.heatmap(titanic.corr(),cmap='plasma')
#titanic.head
# Out:
# <AxesSubplot:>
